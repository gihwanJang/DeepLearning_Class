# %% [markdown]
# # a_single_neuron.py

# %%
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %%
device = torch.device("cpu")

# %%
class SimpleDataset(Dataset):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

        X = [[0.5, 0.9], [14.0, 12.0], [15.0, 13.6],
             [28.0, 22.8], [11.0, 8.1], [8.0, 7.1],
             [3.0, 2.9], [4.0, 0.1], [6.0, 5.3],
             [13.0, 12.0], [21.0, 19.9], [-1.0, 1.5]]

        y = [35.7, 55.9, 58.2, 81.9, 56.3, 48.9, 33.9, 21.8, 48.4, 60.4, 68.4, 29.1]

        self.X = torch.tensor(X, dtype=torch.float, device=device)
        self.y = torch.tensor(y, dtype=torch.float, device=device)
        self.y = self.y * 0.01

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return {'input': self.X[idx], 'target': self.y[idx]}

    def __str__(self):
        str = "Data Size: {0}, Input Shape: {1}, Target Shape: {2}".format(
            len(self.X), self.X.shape, self.y.shape
        )
        return str

# %% [markdown]
# - 2개의 센서에 대한 데이터 셋이라 가정
# - self.X : 센서에 대한 데이터를 tensor로 변환 해당 크기는 ([12,2])
# - self.y : 센서에 대한 데이터 변환 결과를 tensor로 변환 해당 크기는 ([12])
# - self.y * 0.01 : 해당 결과에 대한 정규화

# %%
def model(X, W, b):
    u = torch.sum(X * W, dim=1) + b
    z = activate(u)
    return z

# %% [markdown]
# - 가중치 W를 곱한후 편향 b를 더해줌
# - 가중치(W)는 각 입력값에 대하여 주어지므로 해당 크기는 ([2])가 나옴
# - 편향(b)는 전체에 대한 합산이므로 1개의 값으로 주어짐

# %%
def activate(u):
    return F.sigmoid(u)

# %% [markdown]
# - 활성화 함수로 Sigmoid, Tonh, ReLU, .... 많은 종류가 있음
# - 활성화 함수는 인공 신경망에서 각 뉴런의 출력을 결정하는 역할
# - 뉴런의 입력값을 받아서 어떤 임계값을 기준으로 출력을 생성하거나 제어하는 역할
# - 비선형성 : 활성화 함수는 비선형 함수로 이는 신경망이 복잡한 관계를 학습할 수 있도록 함 만약 활성화 함수가 선형이라면 여러 층을 쌓더라도 결과는 하나의 선형 변환으로 나타나게 되어 효과적으로 층을 여러 번 쌓는 것이 의미가 없음
# - 신경망의 표현력 증가 : 선형 활성화 함수를 사용하면 신경망이 더 복잡한 함수를 근사할 수 있음

# %%
def loss_fn(y_pred, y):
    loss = torch.square(y_pred - y).mean()
    assert loss.shape == () or loss.shape == (1,)
    return loss

# %% [markdown]
# - 손실 함수 : 학습 및 딥 러닝에서 모델의 예측값과 실제 타겟 값 사이의 차이를 측정하는 함수
# - 손실 함수의 값이 작을수록 모델의 예측이 타겟 값에 더 가깝다고 할 수 있음
# - 손실 함수는 모델의 학습 과정에서 사용되어 최적화 알고리즘이 모델 파라미터를 조정
# - 손실 함수의 종류는 MSE, MAE, .... 등이 존재

# %%
def gradient(W, b, X, y):
    y_pred = model(X, W, b)
    dl_dy = 2 * (y_pred - y)
    dl_dy = dl_dy.unsqueeze(dim=-1)  # dl_dy_pred.shape: [12, 1]

    dy_df = 1.0

    z = torch.sum(X * W, dim=-1) + b
    ds_dz = activate(z) * (1.0 - activate(z))
    ds_dz = ds_dz.unsqueeze(dim=-1)  # ds_dz_pred.shape: [12, 1]

    W_grad = torch.mean(dl_dy * dy_df * ds_dz * X, dim=0)
    b_grad = torch.mean(dl_dy * dy_df * ds_dz * 1.0, dim=0)

    return W_grad, b_grad

# %% [markdown]
# - y_pred : 예측값
# -
# - dl_dy : 손실함수의 도함수, 식은 아래와 같음
# - MSE = $\frac{1}{n}\sum _{n}^{i=1}(y_{predic} - y)^{^{2}}$ 해당 식의 미분은 $2(y_{predic} - y)$
# -
# - dy_df : 예측값에 대한 도함수 값은 1
# -
# - ds_dz = 시그모이드 도함수, 식은 아래와 같은
# - sigmoid' = sigmoid(z)(1-sigmoid(z))

# %%
def learn(W, b, train_data_loader):
    MAX_EPOCHS = 20_000
    LEARNING_RATE = 0.01

    for epoch in range(0, MAX_EPOCHS):
        batch = next(iter(train_data_loader))
        y_pred = model(batch["input"], W, b)
        loss = loss_fn(y_pred, batch["target"])

        W_grad, b_grad = gradient(W, b, batch["input"], batch["target"])

        if epoch % 100 == 0:
            print("[Epoch:{0:6,}] loss:{1:8.5f}, w0:{2:6.3f}, w1:{3:6.3f}, b:{4:6.3f}".format(
                epoch, loss.item(), W[0].item(), W[1].item(), b.item()), end=", ")
        print("W.grad: {0}, b.grad:{1}".format(W_grad, b_grad))

        W = W - LEARNING_RATE * W_grad
        b = b - LEARNING_RATE * b_grad

# %% [markdown]
# - epoch : 데이터 전체를 보는 횟수
# - learing_rate : 학습률로 경사하강의 정도를 의미
# - batch : 현제의 모델에서는 len(simple_dataset)
# - y_pred : 현제의 W,b에 대한 예측 값
# - loss : 레이블 값에 대한 예측 값의 손실률(작을 수록 학습이 잘됨)

# %%
def main():
    W = torch.ones((2,))
    b = torch.zeros((1,))

    simple_dataset = SimpleDataset()
    train_data_loader = DataLoader(dataset=simple_dataset, batch_size=len(simple_dataset))
    batch = next(iter(train_data_loader))

    y_pred = model(batch["input"], W, b)
    print(y_pred.shape)
    print(y_pred)

    loss = loss_fn(y_pred, batch["target"])
    print(loss)

    learn(W, b, train_data_loader)

# %%
if __name__ == "__main__":
    main()
# Out:
# torch.Size([12])
# tensor([0.8022, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 0.9973, 0.9837, 1.0000,
#         1.0000, 1.0000, 0.6225])
# tensor(0.2254)
# [Epoch:     0] loss: 0.22539, w0: 1.000, w1: 1.000, b: 0.000, W.grad: tensor([0.0020, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0020, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0020, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0020, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0020, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0020, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0020, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0021, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0021, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0021, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0021, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0021, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0021, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0021, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0021, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0021, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0021, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0022, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0022, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0022, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0022, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0022, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0022, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0022, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0022, 0.0311]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0022, 0.0310]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0022, 0.0310]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0022, 0.0310]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0023, 0.0310]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0023, 0.0310]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0023, 0.0310]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0023, 0.0310]), b.grad:tensor([0.0271])
# W.grad: tensor([0.0023, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0023, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0023, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0023, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0023, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0023, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0024, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0024, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0024, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0024, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0024, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0024, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0024, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0024, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0024, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0024, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0024, 0.0310]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0025, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0025, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0025, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0025, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0025, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0025, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0025, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0025, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0025, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0025, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0026, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0026, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0026, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0026, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0026, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0026, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0026, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0026, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0026, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0026, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0027, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0027, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0027, 0.0309]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0027, 0.0308]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0027, 0.0308]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0027, 0.0308]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0027, 0.0308]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0027, 0.0308]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0027, 0.0308]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0027, 0.0308]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0028, 0.0308]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0028, 0.0308]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0028, 0.0308]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0028, 0.0308]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0028, 0.0308]), b.grad:tensor([0.0270])
# W.grad: tensor([0.0028, 0.0308]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0028, 0.0308]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0028, 0.0308]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0028, 0.0308]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0028, 0.0308]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0029, 0.0308]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0029, 0.0308]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0029, 0.0308]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0029, 0.0308]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0029, 0.0308]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0029, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0029, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0029, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0029, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0029, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0030, 0.0307]), b.grad:tensor([0.0269])
# [Epoch:   100] loss: 0.22369, w0: 0.998, w1: 0.969, b:-0.027, W.grad: tensor([0.0030, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0030, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0030, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0030, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0030, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0030, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0030, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0030, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0030, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0031, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0031, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0031, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0031, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0031, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0031, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0031, 0.0307]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0031, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0031, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0031, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0032, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0032, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0032, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0032, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0032, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0032, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0032, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0032, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0032, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0032, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0033, 0.0306]), b.grad:tensor([0.0269])
# W.grad: tensor([0.0033, 0.0306]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0033, 0.0306]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0033, 0.0306]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0033, 0.0306]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0033, 0.0306]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0033, 0.0306]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0033, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0033, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0034, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0034, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0034, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0034, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0034, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0034, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0034, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0034, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0034, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0034, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0035, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0035, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0035, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0035, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0035, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0035, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0035, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0035, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0035, 0.0305]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0036, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0036, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0036, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0036, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0036, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0036, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0036, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0036, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0036, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0037, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0037, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0037, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0037, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0037, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0037, 0.0304]), b.grad:tensor([0.0268])
# W.grad: tensor([0.0037, 0.0304]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0037, 0.0304]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0037, 0.0304]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0037, 0.0304]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0038, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0038, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0038, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0038, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0038, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0038, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0038, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0038, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0038, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0039, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0039, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0039, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0039, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0039, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0039, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0039, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0039, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0039, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0040, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0040, 0.0303]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0040, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0040, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0040, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0040, 0.0302]), b.grad:tensor([0.0267])
# [Epoch:   200] loss: 0.22203, w0: 0.994, w1: 0.939, b:-0.054, W.grad: tensor([0.0040, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0040, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0040, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0041, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0041, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0041, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0041, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0041, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0041, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0041, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0041, 0.0302]), b.grad:tensor([0.0267])
# W.grad: tensor([0.0041, 0.0302]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0042, 0.0302]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0042, 0.0302]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0042, 0.0302]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0042, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0042, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0042, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0042, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0042, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0042, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0043, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0043, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0043, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0043, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0043, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0043, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0043, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0043, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0043, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0044, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0044, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0044, 0.0301]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0044, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0044, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0044, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0044, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0044, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0044, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0045, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0045, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0045, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0045, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0045, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0045, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0045, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0045, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0045, 0.0300]), b.grad:tensor([0.0266])
# W.grad: tensor([0.0046, 0.0300]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0046, 0.0300]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0046, 0.0300]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0046, 0.0300]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0046, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0046, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0046, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0046, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0047, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0047, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0047, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0047, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0047, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0047, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0047, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0047, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0047, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0048, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0048, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0048, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0048, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0048, 0.0299]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0048, 0.0298]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0048, 0.0298]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0048, 0.0298]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0048, 0.0298]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0049, 0.0298]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0049, 0.0298]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0049, 0.0298]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0049, 0.0298]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0049, 0.0298]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0049, 0.0298]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0049, 0.0298]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0049, 0.0298]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0050, 0.0298]), b.grad:tensor([0.0265])
# W.grad: tensor([0.0050, 0.0298]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0050, 0.0298]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0050, 0.0298]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0050, 0.0298]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0050, 0.0298]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0050, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0050, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0050, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0051, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0051, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0051, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0051, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0051, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0051, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0051, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0051, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0052, 0.0297]), b.grad:tensor([0.0264])
# [Epoch:   300] loss: 0.22041, w0: 0.989, w1: 0.909, b:-0.080, W.grad: tensor([0.0052, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0052, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0052, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0052, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0052, 0.0297]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0052, 0.0296]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0052, 0.0296]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0053, 0.0296]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0053, 0.0296]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0053, 0.0296]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0053, 0.0296]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0053, 0.0296]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0053, 0.0296]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0053, 0.0296]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0053, 0.0296]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0053, 0.0296]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0054, 0.0296]), b.grad:tensor([0.0264])
# W.grad: tensor([0.0054, 0.0296]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0054, 0.0296]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0054, 0.0296]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0054, 0.0296]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0054, 0.0296]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0054, 0.0296]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0054, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0055, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0055, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0055, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0055, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0055, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0055, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0055, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0055, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0056, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0056, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0056, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0056, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0056, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0056, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0056, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0056, 0.0295]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0057, 0.0294]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0057, 0.0294]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0057, 0.0294]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0057, 0.0294]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0057, 0.0294]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0057, 0.0294]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0057, 0.0294]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0057, 0.0294]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0058, 0.0294]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0058, 0.0294]), b.grad:tensor([0.0263])
# W.grad: tensor([0.0058, 0.0294]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0058, 0.0294]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0058, 0.0294]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0058, 0.0294]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0058, 0.0294]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0058, 0.0294]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0058, 0.0294]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0059, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0059, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0059, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0059, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0059, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0059, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0059, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0059, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0060, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0060, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0060, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0060, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0060, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0060, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0060, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0060, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0061, 0.0293]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0061, 0.0292]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0061, 0.0292]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0061, 0.0292]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0061, 0.0292]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0061, 0.0292]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0061, 0.0292]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0062, 0.0292]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0062, 0.0292]), b.grad:tensor([0.0262])
# W.grad: tensor([0.0062, 0.0292]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0062, 0.0292]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0062, 0.0292]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0062, 0.0292]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0062, 0.0292]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0062, 0.0292]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0063, 0.0292]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0063, 0.0292]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0063, 0.0292]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0063, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0063, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0063, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0063, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0063, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0064, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0064, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0064, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0064, 0.0291]), b.grad:tensor([0.0261])
# [Epoch:   400] loss: 0.21882, w0: 0.984, w1: 0.879, b:-0.107, W.grad: tensor([0.0064, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0064, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0064, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0064, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0065, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0065, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0065, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0065, 0.0291]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0065, 0.0290]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0065, 0.0290]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0065, 0.0290]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0065, 0.0290]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0066, 0.0290]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0066, 0.0290]), b.grad:tensor([0.0261])
# W.grad: tensor([0.0066, 0.0290]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0066, 0.0290]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0066, 0.0290]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0066, 0.0290]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0066, 0.0290]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0067, 0.0290]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0067, 0.0290]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0067, 0.0290]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0067, 0.0290]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0067, 0.0290]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0067, 0.0290]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0067, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0067, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0068, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0068, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0068, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0068, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0068, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0068, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0068, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0068, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0069, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0069, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0069, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0069, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0069, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0069, 0.0289]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0069, 0.0288]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0070, 0.0288]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0070, 0.0288]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0070, 0.0288]), b.grad:tensor([0.0260])
# W.grad: tensor([0.0070, 0.0288]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0070, 0.0288]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0070, 0.0288]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0070, 0.0288]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0070, 0.0288]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0071, 0.0288]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0071, 0.0288]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0071, 0.0288]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0071, 0.0288]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0071, 0.0288]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0071, 0.0288]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0071, 0.0288]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0072, 0.0288]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0072, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0072, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0072, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0072, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0072, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0072, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0072, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0073, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0073, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0073, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0073, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0073, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0073, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0073, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0074, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0074, 0.0287]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0074, 0.0286]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0074, 0.0286]), b.grad:tensor([0.0259])
# W.grad: tensor([0.0074, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0074, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0074, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0074, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0075, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0075, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0075, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0075, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0075, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0075, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0075, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0076, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0076, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0076, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0076, 0.0286]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0076, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0076, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0076, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0077, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0077, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0077, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0077, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0077, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0077, 0.0285]), b.grad:tensor([0.0258])
# [Epoch:   500] loss: 0.21727, w0: 0.977, w1: 0.850, b:-0.133, W.grad: tensor([0.0077, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0077, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0078, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0078, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0078, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0078, 0.0285]), b.grad:tensor([0.0258])
# W.grad: tensor([0.0078, 0.0285]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0078, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0078, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0079, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0079, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0079, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0079, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0079, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0079, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0079, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0080, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0080, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0080, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0080, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0080, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0080, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0080, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0081, 0.0284]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0081, 0.0283]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0081, 0.0283]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0081, 0.0283]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0081, 0.0283]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0081, 0.0283]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0081, 0.0283]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0082, 0.0283]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0082, 0.0283]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0082, 0.0283]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0082, 0.0283]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0082, 0.0283]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0082, 0.0283]), b.grad:tensor([0.0257])
# W.grad: tensor([0.0082, 0.0283]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0083, 0.0283]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0083, 0.0283]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0083, 0.0283]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0083, 0.0283]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0083, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0083, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0083, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0084, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0084, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0084, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0084, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0084, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0084, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0084, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0085, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0085, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0085, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0085, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0085, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0085, 0.0282]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0085, 0.0281]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0086, 0.0281]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0086, 0.0281]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0086, 0.0281]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0086, 0.0281]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0086, 0.0281]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0086, 0.0281]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0086, 0.0281]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0087, 0.0281]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0087, 0.0281]), b.grad:tensor([0.0256])
# W.grad: tensor([0.0087, 0.0281]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0087, 0.0281]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0087, 0.0281]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0087, 0.0281]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0087, 0.0281]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0088, 0.0281]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0088, 0.0281]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0088, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0088, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0088, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0088, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0088, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0089, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0089, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0089, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0089, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0089, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0089, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0089, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0090, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0090, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0090, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0090, 0.0280]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0090, 0.0279]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0090, 0.0279]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0090, 0.0279]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0091, 0.0279]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0091, 0.0279]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0091, 0.0279]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0091, 0.0279]), b.grad:tensor([0.0255])
# W.grad: tensor([0.0091, 0.0279]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0091, 0.0279]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0091, 0.0279]), b.grad:tensor([0.0254])
# [Epoch:   600] loss: 0.21575, w0: 0.968, w1: 0.822, b:-0.158, W.grad: tensor([0.0092, 0.0279]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0092, 0.0279]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0092, 0.0279]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0092, 0.0279]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0092, 0.0279]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0092, 0.0279]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0093, 0.0279]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0093, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0093, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0093, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0093, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0093, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0093, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0094, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0094, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0094, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0094, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0094, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0094, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0094, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0095, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0095, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0095, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0095, 0.0278]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0095, 0.0277]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0095, 0.0277]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0096, 0.0277]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0096, 0.0277]), b.grad:tensor([0.0254])
# W.grad: tensor([0.0096, 0.0277]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0096, 0.0277]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0096, 0.0277]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0096, 0.0277]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0096, 0.0277]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0097, 0.0277]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0097, 0.0277]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0097, 0.0277]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0097, 0.0277]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0097, 0.0277]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0097, 0.0277]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0097, 0.0277]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0098, 0.0277]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0098, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0098, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0098, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0098, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0098, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0099, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0099, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0099, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0099, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0099, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0099, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0099, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0100, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0100, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0100, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0100, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0100, 0.0276]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0100, 0.0275]), b.grad:tensor([0.0253])
# W.grad: tensor([0.0101, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0101, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0101, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0101, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0101, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0101, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0101, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0102, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0102, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0102, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0102, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0102, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0102, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0103, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0103, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0103, 0.0275]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0103, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0103, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0103, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0104, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0104, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0104, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0104, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0104, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0104, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0104, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0105, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0105, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0105, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0105, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0105, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0105, 0.0274]), b.grad:tensor([0.0252])
# W.grad: tensor([0.0106, 0.0274]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0106, 0.0274]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0106, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0106, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0106, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0106, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0107, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0107, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0107, 0.0273]), b.grad:tensor([0.0251])
# [Epoch:   700] loss: 0.21425, w0: 0.958, w1: 0.795, b:-0.183, W.grad: tensor([0.0107, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0107, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0107, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0107, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0108, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0108, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0108, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0108, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0108, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0108, 0.0273]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0109, 0.0272]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0109, 0.0272]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0109, 0.0272]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0109, 0.0272]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0109, 0.0272]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0109, 0.0272]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0110, 0.0272]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0110, 0.0272]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0110, 0.0272]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0110, 0.0272]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0110, 0.0272]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0110, 0.0272]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0111, 0.0272]), b.grad:tensor([0.0251])
# W.grad: tensor([0.0111, 0.0272]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0111, 0.0272]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0111, 0.0272]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0111, 0.0272]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0111, 0.0272]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0112, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0112, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0112, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0112, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0112, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0112, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0113, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0113, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0113, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0113, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0113, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0113, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0114, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0114, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0114, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0114, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0114, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0114, 0.0271]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0114, 0.0270]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0115, 0.0270]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0115, 0.0270]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0115, 0.0270]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0115, 0.0270]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0115, 0.0270]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0115, 0.0270]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0116, 0.0270]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0116, 0.0270]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0116, 0.0270]), b.grad:tensor([0.0250])
# W.grad: tensor([0.0116, 0.0270]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0116, 0.0270]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0116, 0.0270]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0117, 0.0270]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0117, 0.0270]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0117, 0.0270]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0117, 0.0270]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0117, 0.0270]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0118, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0118, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0118, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0118, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0118, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0118, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0119, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0119, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0119, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0119, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0119, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0119, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0120, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0120, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0120, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0120, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0120, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0120, 0.0269]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0121, 0.0268]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0121, 0.0268]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0121, 0.0268]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0121, 0.0268]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0121, 0.0268]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0121, 0.0268]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0122, 0.0268]), b.grad:tensor([0.0249])
# W.grad: tensor([0.0122, 0.0268]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0122, 0.0268]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0122, 0.0268]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0122, 0.0268]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0122, 0.0268]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0123, 0.0268]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0123, 0.0268]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0123, 0.0268]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0123, 0.0268]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0123, 0.0268]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0123, 0.0268]), b.grad:tensor([0.0248])
# [Epoch:   800] loss: 0.21276, w0: 0.947, w1: 0.768, b:-0.208, W.grad: tensor([0.0124, 0.0268]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0124, 0.0267]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0124, 0.0267]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0124, 0.0267]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0124, 0.0267]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0125, 0.0267]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0125, 0.0267]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0125, 0.0267]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0125, 0.0267]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0125, 0.0267]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0125, 0.0267]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0126, 0.0267]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0126, 0.0267]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0126, 0.0267]), b.grad:tensor([0.0248])
# W.grad: tensor([0.0126, 0.0267]), b.grad:tensor([0.0248])
# ...
# W.grad: tensor([-3.8184e-07, -3.3155e-07]), b.grad:tensor([8.4887e-06])
# W.grad: tensor([-4.0171e-07, -3.4645e-07]), b.grad:tensor([8.4853e-06])
# W.grad: tensor([-4.0171e-07, -3.4645e-07]), b.grad:tensor([8.4853e-06])
# W.grad: tensor([-3.5577e-07, -3.0796e-07]), b.grad:tensor([8.4847e-06])
# W.grad: tensor([-4.1785e-07, -3.6570e-07]), b.grad:tensor([8.4772e-06])
# W.grad: tensor([-3.7315e-07, -3.2596e-07]), b.grad:tensor([8.4772e-06])
# W.grad: tensor([-3.9178e-07, -3.4769e-07]), b.grad:tensor([8.4729e-06])
# W.grad: tensor([-4.2655e-07, -3.7253e-07]), b.grad:tensor([8.4704e-06])
# W.grad: tensor([-3.6601e-07, -3.2969e-07]), b.grad:tensor([8.4710e-06])
# W.grad: tensor([-4.5542e-07, -4.0419e-07]), b.grad:tensor([8.4654e-06])
# W.grad: tensor([-3.4024e-07, -3.0672e-07]), b.grad:tensor([8.4691e-06])
# W.grad: tensor([-3.6011e-07, -3.2162e-07]), b.grad:tensor([8.4667e-06])
# W.grad: tensor([-2.5580e-07, -2.2600e-07]), b.grad:tensor([8.4657e-06])
# W.grad: tensor([-3.8495e-07, -3.3776e-07]), b.grad:tensor([8.4608e-06])
# W.grad: tensor([-3.8495e-07, -3.3279e-07]), b.grad:tensor([8.4589e-06])
# W.grad: tensor([-3.3528e-07, -2.8561e-07]), b.grad:tensor([8.4567e-06])
# W.grad: tensor([-3.3279e-07, -2.8312e-07]), b.grad:tensor([8.4539e-06])
# W.grad: tensor([-3.4273e-07, -2.9802e-07]), b.grad:tensor([8.4524e-06])
# W.grad: tensor([-3.5142e-07, -2.9926e-07]), b.grad:tensor([8.4480e-06])
# W.grad: tensor([-3.5142e-07, -2.9926e-07]), b.grad:tensor([8.4480e-06])
# [Epoch:19,800] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-3.8495e-07, -3.3528e-07]), b.grad:tensor([8.4415e-06])
# W.grad: tensor([-3.8991e-07, -3.3031e-07]), b.grad:tensor([8.4400e-06])
# W.grad: tensor([-3.4521e-07, -3.0299e-07]), b.grad:tensor([8.4375e-06])
# W.grad: tensor([-3.7998e-07, -3.2783e-07]), b.grad:tensor([8.4350e-06])
# W.grad: tensor([-3.5887e-07, -3.0920e-07]), b.grad:tensor([8.4337e-06])
# W.grad: tensor([-3.9271e-07, -3.4086e-07]), b.grad:tensor([8.4303e-06])
# W.grad: tensor([-3.9892e-07, -3.4086e-07]), b.grad:tensor([8.4275e-06])
# W.grad: tensor([-4.0295e-07, -3.4769e-07]), b.grad:tensor([8.4254e-06])
# W.grad: tensor([-4.0792e-07, -3.5266e-07]), b.grad:tensor([8.4235e-06])
# W.grad: tensor([-4.4766e-07, -3.9736e-07]), b.grad:tensor([8.4182e-06])
# W.grad: tensor([-3.1355e-07, -2.7319e-07]), b.grad:tensor([8.4272e-06])
# W.grad: tensor([-3.2596e-07, -2.8002e-07]), b.grad:tensor([8.4235e-06])
# W.grad: tensor([-3.2596e-07, -2.8002e-07]), b.grad:tensor([8.4226e-06])
# W.grad: tensor([-3.2472e-07, -2.8188e-07]), b.grad:tensor([8.4201e-06])
# W.grad: tensor([-3.2969e-07, -2.8188e-07]), b.grad:tensor([8.4188e-06])
# W.grad: tensor([-3.7315e-07, -3.2286e-07]), b.grad:tensor([8.4133e-06])
# W.grad: tensor([-3.1479e-07, -2.7753e-07]), b.grad:tensor([8.4126e-06])
# W.grad: tensor([-4.1661e-07, -3.6073e-07]), b.grad:tensor([8.4052e-06])
# W.grad: tensor([-3.6322e-07, -3.2410e-07]), b.grad:tensor([8.4058e-06])
# W.grad: tensor([-4.0792e-07, -3.6384e-07]), b.grad:tensor([8.4002e-06])
# W.grad: tensor([-3.8184e-07, -3.3590e-07]), b.grad:tensor([8.3968e-06])
# W.grad: tensor([-4.4641e-07, -3.9550e-07]), b.grad:tensor([8.3909e-06])
# W.grad: tensor([-3.0361e-07, -2.6636e-07]), b.grad:tensor([8.3990e-06])
# W.grad: tensor([-3.7315e-07, -3.2596e-07]), b.grad:tensor([8.3928e-06])
# W.grad: tensor([-4.0699e-07, -3.6259e-07]), b.grad:tensor([8.3869e-06])
# W.grad: tensor([-3.7719e-07, -3.3776e-07]), b.grad:tensor([8.3881e-06])
# W.grad: tensor([-4.1599e-07, -3.6880e-07]), b.grad:tensor([8.3835e-06])
# W.grad: tensor([-3.1541e-07, -2.8685e-07]), b.grad:tensor([8.3866e-06])
# W.grad: tensor([-4.6442e-07, -4.1102e-07]), b.grad:tensor([8.3757e-06])
# W.grad: tensor([-2.0489e-07, -1.9496e-07]), b.grad:tensor([8.3906e-06])
# W.grad: tensor([-2.3842e-07, -2.1607e-07]), b.grad:tensor([8.3844e-06])
# W.grad: tensor([-3.1292e-07, -2.7567e-07]), b.grad:tensor([8.3772e-06])
# W.grad: tensor([-2.7319e-07, -2.4773e-07]), b.grad:tensor([8.3748e-06])
# W.grad: tensor([-3.4024e-07, -3.0920e-07]), b.grad:tensor([8.3686e-06])
# W.grad: tensor([-3.7501e-07, -3.3900e-07]), b.grad:tensor([8.3661e-06])
# W.grad: tensor([-3.0051e-07, -2.7567e-07]), b.grad:tensor([8.3661e-06])
# W.grad: tensor([-3.7005e-07, -3.3528e-07]), b.grad:tensor([8.3617e-06])
# W.grad: tensor([-3.5514e-07, -3.2037e-07]), b.grad:tensor([8.3592e-06])
# W.grad: tensor([-3.8991e-07, -3.5018e-07]), b.grad:tensor([8.3561e-06])
# W.grad: tensor([-3.9364e-07, -3.5266e-07]), b.grad:tensor([8.3537e-06])
# W.grad: tensor([-3.9364e-07, -3.5266e-07]), b.grad:tensor([8.3540e-06])
# W.grad: tensor([-4.1258e-07, -3.6880e-07]), b.grad:tensor([8.3478e-06])
# W.grad: tensor([-4.1258e-07, -3.7377e-07]), b.grad:tensor([8.3468e-06])
# W.grad: tensor([-3.1727e-07, -2.9119e-07]), b.grad:tensor([8.3487e-06])
# W.grad: tensor([-3.2224e-07, -2.9119e-07]), b.grad:tensor([8.3474e-06])
# W.grad: tensor([-3.5577e-07, -3.2286e-07]), b.grad:tensor([8.3437e-06])
# W.grad: tensor([-3.5577e-07, -3.2783e-07]), b.grad:tensor([8.3425e-06])
# W.grad: tensor([-3.1230e-07, -2.9244e-07]), b.grad:tensor([8.3419e-06])
# W.grad: tensor([-3.7439e-07, -3.3590e-07]), b.grad:tensor([8.3369e-06])
# W.grad: tensor([-3.6073e-07, -3.3403e-07]), b.grad:tensor([8.3332e-06])
# W.grad: tensor([-3.7563e-07, -3.4397e-07]), b.grad:tensor([8.3297e-06])
# W.grad: tensor([-4.0047e-07, -3.5887e-07]), b.grad:tensor([8.3260e-06])
# W.grad: tensor([-4.0544e-07, -3.5887e-07]), b.grad:tensor([8.3248e-06])
# W.grad: tensor([-4.0916e-07, -3.7501e-07]), b.grad:tensor([8.3204e-06])
# W.grad: tensor([-3.5825e-07, -3.3714e-07]), b.grad:tensor([8.3211e-06])
# W.grad: tensor([-3.2845e-07, -3.0734e-07]), b.grad:tensor([8.3204e-06])
# W.grad: tensor([-3.6694e-07, -3.3900e-07]), b.grad:tensor([8.3161e-06])
# W.grad: tensor([-3.6694e-07, -3.3900e-07]), b.grad:tensor([8.3155e-06])
# W.grad: tensor([-3.3124e-07, -3.1106e-07]), b.grad:tensor([8.3167e-06])
# W.grad: tensor([-3.9085e-07, -3.5577e-07]), b.grad:tensor([8.3105e-06])
# W.grad: tensor([-3.6508e-07, -3.3279e-07]), b.grad:tensor([8.3108e-06])
# W.grad: tensor([-4.0978e-07, -3.7750e-07]), b.grad:tensor([8.3040e-06])
# W.grad: tensor([-2.0489e-07, -1.9620e-07]), b.grad:tensor([8.3127e-06])
# W.grad: tensor([-2.6325e-07, -2.3780e-07]), b.grad:tensor([8.3065e-06])
# W.grad: tensor([-2.6325e-07, -2.3780e-07]), b.grad:tensor([8.3058e-06])
# W.grad: tensor([-2.9802e-07, -2.7257e-07]), b.grad:tensor([8.3009e-06])
# W.grad: tensor([-2.7815e-07, -2.5270e-07]), b.grad:tensor([8.3009e-06])
# W.grad: tensor([-3.2162e-07, -2.9430e-07]), b.grad:tensor([8.2953e-06])
# W.grad: tensor([-2.9181e-07, -2.7443e-07]), b.grad:tensor([8.2934e-06])
# W.grad: tensor([-3.4055e-07, -3.1541e-07]), b.grad:tensor([8.2906e-06])
# W.grad: tensor([-3.5670e-07, -3.2037e-07]), b.grad:tensor([8.2869e-06])
# W.grad: tensor([-3.4024e-07, -3.1789e-07]), b.grad:tensor([8.2838e-06])
# W.grad: tensor([-3.0951e-07, -2.9430e-07]), b.grad:tensor([8.2838e-06])
# W.grad: tensor([-3.9271e-07, -3.6880e-07]), b.grad:tensor([8.2779e-06])
# W.grad: tensor([-3.7067e-07, -3.5080e-07]), b.grad:tensor([8.2751e-06])
# W.grad: tensor([-3.8060e-07, -3.5080e-07]), b.grad:tensor([8.2729e-06])
# W.grad: tensor([-3.8929e-07, -3.6259e-07]), b.grad:tensor([8.2692e-06])
# W.grad: tensor([-4.1537e-07, -3.8370e-07]), b.grad:tensor([8.2642e-06])
# W.grad: tensor([-2.8374e-07, -2.6574e-07]), b.grad:tensor([8.2732e-06])
# W.grad: tensor([-3.7315e-07, -3.5018e-07]), b.grad:tensor([8.2646e-06])
# W.grad: tensor([-3.8929e-07, -3.6011e-07]), b.grad:tensor([8.2633e-06])
# W.grad: tensor([-3.8184e-07, -3.6135e-07]), b.grad:tensor([8.2615e-06])
# W.grad: tensor([-3.5577e-07, -3.3403e-07]), b.grad:tensor([8.2602e-06])
# W.grad: tensor([-3.7067e-07, -3.4397e-07]), b.grad:tensor([8.2537e-06])
# W.grad: tensor([-4.3400e-07, -4.0481e-07]), b.grad:tensor([8.2481e-06])
# W.grad: tensor([-2.8498e-07, -2.7070e-07]), b.grad:tensor([8.2574e-06])
# W.grad: tensor([-3.1727e-07, -2.9244e-07]), b.grad:tensor([8.2521e-06])
# W.grad: tensor([-3.5204e-07, -3.1727e-07]), b.grad:tensor([8.2497e-06])
# W.grad: tensor([-2.2569e-07, -2.2103e-07]), b.grad:tensor([8.2534e-06])
# W.grad: tensor([-4.0575e-07, -3.7377e-07]), b.grad:tensor([8.2416e-06])
# W.grad: tensor([-1.3504e-07, -1.4839e-07]), b.grad:tensor([8.2540e-06])
# W.grad: tensor([-2.1451e-07, -2.1296e-07]), b.grad:tensor([8.2466e-06])
# W.grad: tensor([-2.5301e-07, -2.4959e-07]), b.grad:tensor([8.2428e-06])
# W.grad: tensor([-2.9895e-07, -2.8436e-07]), b.grad:tensor([8.2360e-06])
# W.grad: tensor([-2.6915e-07, -2.5953e-07]), b.grad:tensor([8.2379e-06])
# W.grad: tensor([-3.0392e-07, -2.8933e-07]), b.grad:tensor([8.2326e-06])
# W.grad: tensor([-3.6756e-07, -3.4521e-07]), b.grad:tensor([8.2251e-06])
# W.grad: tensor([-3.3776e-07, -3.1541e-07]), b.grad:tensor([8.2254e-06])
# W.grad: tensor([-3.4645e-07, -3.3217e-07]), b.grad:tensor([8.2208e-06])
# W.grad: tensor([-2.9926e-07, -2.9368e-07]), b.grad:tensor([8.2226e-06])
# [Epoch:19,900] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-3.5390e-07, -3.3900e-07]), b.grad:tensor([8.2174e-06])
# W.grad: tensor([-3.5887e-07, -3.3900e-07]), b.grad:tensor([8.2161e-06])
# W.grad: tensor([-3.4521e-07, -3.2162e-07]), b.grad:tensor([8.2118e-06])
# W.grad: tensor([-3.4428e-07, -3.2348e-07]), b.grad:tensor([8.2112e-06])
# W.grad: tensor([-3.4428e-07, -3.2348e-07]), b.grad:tensor([8.2099e-06])
# W.grad: tensor([-3.7408e-07, -3.5514e-07]), b.grad:tensor([8.2025e-06])
# W.grad: tensor([-3.8402e-07, -3.6508e-07]), b.grad:tensor([8.2003e-06])
# W.grad: tensor([-4.1878e-07, -3.9488e-07]), b.grad:tensor([8.1978e-06])
# W.grad: tensor([-3.3559e-07, -3.2534e-07]), b.grad:tensor([8.2009e-06])
# W.grad: tensor([-3.8402e-07, -3.6322e-07]), b.grad:tensor([8.1947e-06])
# W.grad: tensor([-3.6911e-07, -3.5328e-07]), b.grad:tensor([8.1947e-06])
# W.grad: tensor([-3.9178e-07, -3.6508e-07]), b.grad:tensor([8.1885e-06])
# W.grad: tensor([-4.2655e-07, -3.9488e-07]), b.grad:tensor([8.1866e-06])
# W.grad: tensor([-3.3590e-07, -3.1665e-07]), b.grad:tensor([8.1904e-06])
# W.grad: tensor([-3.6570e-07, -3.3652e-07]), b.grad:tensor([8.1866e-06])
# W.grad: tensor([-3.6446e-07, -3.3900e-07]), b.grad:tensor([8.1842e-06])
# W.grad: tensor([-3.7812e-07, -3.5514e-07]), b.grad:tensor([8.1801e-06])
# W.grad: tensor([-3.8433e-07, -3.6011e-07]), b.grad:tensor([8.1767e-06])
# W.grad: tensor([-3.3466e-07, -3.2348e-07]), b.grad:tensor([8.1786e-06])
# W.grad: tensor([-3.3466e-07, -3.2845e-07]), b.grad:tensor([8.1748e-06])
# W.grad: tensor([-3.9799e-07, -3.7191e-07]), b.grad:tensor([8.1730e-06])
# W.grad: tensor([-3.4831e-07, -3.3341e-07]), b.grad:tensor([8.1727e-06])
# W.grad: tensor([-3.4738e-07, -3.3528e-07]), b.grad:tensor([8.1720e-06])
# W.grad: tensor([-3.7719e-07, -3.5514e-07]), b.grad:tensor([8.1671e-06])
# W.grad: tensor([-3.8091e-07, -3.6197e-07]), b.grad:tensor([8.1634e-06])
# W.grad: tensor([-3.8091e-07, -3.6197e-07]), b.grad:tensor([8.1634e-06])
# W.grad: tensor([-3.9457e-07, -3.7874e-07]), b.grad:tensor([8.1571e-06])
# W.grad: tensor([-2.9771e-07, -3.0051e-07]), b.grad:tensor([8.1596e-06])
# W.grad: tensor([-2.7691e-07, -2.7691e-07]), b.grad:tensor([8.1602e-06])
# W.grad: tensor([-3.2658e-07, -3.3155e-07]), b.grad:tensor([8.1528e-06])
# W.grad: tensor([-3.3155e-07, -3.3341e-07]), b.grad:tensor([8.1500e-06])
# W.grad: tensor([-3.4148e-07, -3.3341e-07]), b.grad:tensor([8.1488e-06])
# W.grad: tensor([-3.4397e-07, -3.3528e-07]), b.grad:tensor([8.1466e-06])
# W.grad: tensor([-3.7253e-07, -3.5701e-07]), b.grad:tensor([8.1422e-06])
# W.grad: tensor([-3.7253e-07, -3.6197e-07]), b.grad:tensor([8.1413e-06])
# W.grad: tensor([-3.7750e-07, -3.6197e-07]), b.grad:tensor([8.1388e-06])
# W.grad: tensor([-3.8743e-07, -3.7191e-07]), b.grad:tensor([8.1370e-06])
# W.grad: tensor([-3.9612e-07, -3.9364e-07]), b.grad:tensor([8.1314e-06])
# W.grad: tensor([-3.1044e-07, -3.0547e-07]), b.grad:tensor([8.1382e-06])
# W.grad: tensor([-3.1944e-07, -3.2162e-07]), b.grad:tensor([8.1326e-06])
# W.grad: tensor([-2.8467e-07, -2.8809e-07]), b.grad:tensor([8.1320e-06])
# W.grad: tensor([-3.4304e-07, -3.3466e-07]), b.grad:tensor([8.1258e-06])
# W.grad: tensor([-4.1382e-07, -3.8433e-07]), b.grad:tensor([8.1196e-06])
# W.grad: tensor([-2.6356e-07, -2.6698e-07]), b.grad:tensor([8.1264e-06])
# W.grad: tensor([-2.9709e-07, -2.9181e-07]), b.grad:tensor([8.1218e-06])
# W.grad: tensor([-3.1603e-07, -3.0858e-07]), b.grad:tensor([8.1183e-06])
# W.grad: tensor([-3.2100e-07, -3.1851e-07]), b.grad:tensor([8.1159e-06])
# W.grad: tensor([-3.4459e-07, -3.3031e-07]), b.grad:tensor([8.1106e-06])
# W.grad: tensor([-3.4459e-07, -3.3031e-07]), b.grad:tensor([8.1093e-06])
# W.grad: tensor([-3.5452e-07, -3.4024e-07]), b.grad:tensor([8.1069e-06])
# W.grad: tensor([-3.8929e-07, -3.7005e-07]), b.grad:tensor([8.1050e-06])
# W.grad: tensor([-2.5767e-07, -2.6822e-07]), b.grad:tensor([8.1087e-06])
# W.grad: tensor([-3.9302e-07, -3.8619e-07]), b.grad:tensor([8.1000e-06])
# W.grad: tensor([-2.6760e-07, -2.8064e-07]), b.grad:tensor([8.1034e-06])
# W.grad: tensor([-2.3780e-07, -2.5084e-07]), b.grad:tensor([8.1041e-06])
# W.grad: tensor([-2.7629e-07, -2.8685e-07]), b.grad:tensor([8.0985e-06])
# W.grad: tensor([-4.3027e-07, -4.0978e-07]), b.grad:tensor([8.0895e-06])
# W.grad: tensor([-2.1948e-07, -2.2911e-07]), b.grad:tensor([8.0988e-06])
# W.grad: tensor([-2.6915e-07, -2.7381e-07]), b.grad:tensor([8.0941e-06])
# W.grad: tensor([-2.9026e-07, -3.0175e-07]), b.grad:tensor([8.0867e-06])
# W.grad: tensor([-2.5549e-07, -2.6698e-07]), b.grad:tensor([8.0888e-06])
# W.grad: tensor([-3.6632e-07, -3.6135e-07]), b.grad:tensor([8.0792e-06])
# W.grad: tensor([-2.8436e-07, -2.9306e-07]), b.grad:tensor([8.0823e-06])
# W.grad: tensor([-2.9306e-07, -3.0051e-07]), b.grad:tensor([8.0777e-06])
# W.grad: tensor([-3.7377e-07, -3.6011e-07]), b.grad:tensor([8.0712e-06])
# W.grad: tensor([-3.1292e-07, -3.1168e-07]), b.grad:tensor([8.0721e-06])
# W.grad: tensor([-4.1227e-07, -3.9116e-07]), b.grad:tensor([8.0646e-06])
# W.grad: tensor([-2.6325e-07, -2.7381e-07]), b.grad:tensor([8.0715e-06])
# W.grad: tensor([-3.1168e-07, -3.1355e-07]), b.grad:tensor([8.0696e-06])
# W.grad: tensor([-3.7005e-07, -3.6011e-07]), b.grad:tensor([8.0606e-06])
# W.grad: tensor([-3.2534e-07, -3.2037e-07]), b.grad:tensor([8.0612e-06])
# W.grad: tensor([-3.4397e-07, -3.4148e-07]), b.grad:tensor([8.0559e-06])
# W.grad: tensor([-4.3089e-07, -4.1227e-07]), b.grad:tensor([8.0507e-06])
# W.grad: tensor([-3.1199e-07, -3.0982e-07]), b.grad:tensor([8.0544e-06])
# W.grad: tensor([-3.1199e-07, -3.0982e-07]), b.grad:tensor([8.0544e-06])
# W.grad: tensor([-3.5204e-07, -3.4645e-07]), b.grad:tensor([8.0485e-06])
# W.grad: tensor([-3.6694e-07, -3.6135e-07]), b.grad:tensor([8.0454e-06])
# W.grad: tensor([-3.6197e-07, -3.6135e-07]), b.grad:tensor([8.0441e-06])
# W.grad: tensor([-3.7191e-07, -3.6632e-07]), b.grad:tensor([8.0420e-06])
# W.grad: tensor([-3.2193e-07, -3.2845e-07]), b.grad:tensor([8.0410e-06])
# W.grad: tensor([-3.9147e-07, -3.8805e-07]), b.grad:tensor([8.0355e-06])
# W.grad: tensor([-2.3159e-07, -2.4090e-07]), b.grad:tensor([8.0448e-06])
# W.grad: tensor([-2.4152e-07, -2.4090e-07]), b.grad:tensor([8.0417e-06])
# W.grad: tensor([-3.3962e-07, -3.4148e-07]), b.grad:tensor([8.0333e-06])
# W.grad: tensor([-2.9864e-07, -2.9678e-07]), b.grad:tensor([8.0327e-06])
# W.grad: tensor([-3.6818e-07, -3.6818e-07]), b.grad:tensor([8.0261e-06])
# W.grad: tensor([-3.7688e-07, -3.7501e-07]), b.grad:tensor([8.0215e-06])
# W.grad: tensor([-1.6329e-07, -1.8378e-07]), b.grad:tensor([8.0317e-06])
# W.grad: tensor([-2.0303e-07, -2.1855e-07]), b.grad:tensor([8.0280e-06])
# W.grad: tensor([-2.0675e-07, -2.3035e-07]), b.grad:tensor([8.0255e-06])
# W.grad: tensor([-2.7629e-07, -2.8002e-07]), b.grad:tensor([8.0187e-06])
# W.grad: tensor([-3.4490e-07, -3.4645e-07]), b.grad:tensor([8.0125e-06])
# W.grad: tensor([-3.3993e-07, -3.4645e-07]), b.grad:tensor([8.0103e-06])
# W.grad: tensor([-3.8464e-07, -3.8122e-07]), b.grad:tensor([8.0072e-06])
# W.grad: tensor([-2.9895e-07, -3.1355e-07]), b.grad:tensor([8.0072e-06])
# W.grad: tensor([-2.1327e-07, -2.2414e-07]), b.grad:tensor([8.0106e-06])
# W.grad: tensor([-3.1168e-07, -3.2037e-07]), b.grad:tensor([8.0044e-06])
# W.grad: tensor([-3.1168e-07, -3.1541e-07]), b.grad:tensor([8.0013e-06])
# W.grad: tensor([-3.5514e-07, -3.6632e-07]), b.grad:tensor([7.9945e-06])
# W.grad: tensor([-3.5142e-07, -3.5266e-07]), b.grad:tensor([7.9911e-06])

# %% [markdown]
# # b_autograd_1.py

# %%
import torch

# %%
w = torch.ones(3, requires_grad=True)
print(w)
print(w.grad, w.grad_fn)
# Out:
# tensor([1., 1., 1.], requires_grad=True)
# None None

# %% [markdown]
# - requires_grad : computational 그래프의 노드의 시작으로 만들겠다는 의미
# - w의 grad와 grad_fn이 생성됨

# %%
c = torch.tensor([2])
x = w + c
print(x)
print(x.grad_fn)
# Out:
# tensor([3., 3., 3.], grad_fn=<AddBackward0>)
# <AddBackward0 object at 0x1743b8190>

# %% [markdown]
# - c는 requires_grad가 않되어 있지만 되어 있는 것과 더하면 true와 동일하게 적용이 됨
# - 해당 c는 computational 그래프에 값이 적용 되지 않음
# - 이때 grad는 동일하게 none이지만 grad_fn은 add를 통하여 만들어졌다는 것을 유지

# %%
y = x * 3
print(y)
print(y.grad_fn)
# Out:
# tensor([9., 9., 9.], grad_fn=<MulBackward0>)
# <MulBackward0 object at 0x1743b83a0>

# %% [markdown]
# - 위와 동일하게 grad는 동일하게 none이지만 grad_fn은 mul을 통하여 만들어졌다는 것을 유지

# %%
z = y.mean()
print(z)
print(z.shape)
print(z.grad_fn)
# Out:
# tensor(9., grad_fn=<MeanBackward0>)
# torch.Size([])
# <MeanBackward0 object at 0x1743bf8b0>

# %% [markdown]
# - 위와 동일하게 grad는 동일하게 none이지만 grad_fn은 mean을 통하여 만들어졌다는 것을 유지

# %%
z.backward()

# print(z.grad)
# print(y.grad)
# print(x.grad)
print(w.grad)
# Out:
# tensor([1., 1., 1.])

# %% [markdown]
# - z.backward() : 통합 자동미분 이전의 연산들에 대하여 유지 하고 있음으로 가능
# - grad의 접근에 대하여는 말단 노드에 대하여만 접근이 가능하며 중간의 노드에 대한 접근은 y.retain_grad()과 같은 방식으로 접근 가능

# %% [markdown]
# # c_autograd_2.py

# %%
import torch

# %%
a = torch.randn(2, 2)
print(a.requires_grad)

b = ((a * 3) / (a - 1))
print(b.grad_fn)

# b.backward()
# Out:
# False
# None

# %% [markdown]
# - requires_grad -> false
# - b.backward()는 그래프가 그려져 있지 않아 사용 할 수 없음

# %%
a.requires_grad_(True)

print(a.requires_grad)

c = (a * a).sum()
print(c.grad_fn)

c.backward()

print(a.grad)
# Out:
# True
# <SumBackward0 object at 0x1743b81f0>
# tensor([[ 1.6537, -0.9392],
#         [-1.4761, -1.3360]])

# %% [markdown]
# - requires_grad_(true)로 requires_grad를 현제 상태부터 computation 그래프를 그릴 수 있음
# - 그러므로 c.backward()가 가능

# %%
a = torch.randn(2, 2, requires_grad=True)
print(a.requires_grad)
b = a.detach()
print(b.requires_grad)
print(b is a)
# Out:
# True
# False
# False

# %%
from torchviz import make_dot

# %%
x = torch.ones(3, requires_grad=True)
y = 2 * x
z = 3 + x
r = (y + z).sum()
make_dot(r).render("./img/torchviz_1", format="png")

# Detach
x = torch.ones(3, requires_grad=True)
y = 2 * x
z = 3 + x.detach()
r = (y + z).sum()
make_dot(r).render("./img/torchviz_2", format="png")
# Out:
# 'img/torchviz_2.png'

# %%
a = torch.randn(2, 2, requires_grad=True)
b = a * 2
make_dot(b).render("./img/torchviz_3", format="png")

a = torch.randn(2, 2, requires_grad=True)
print(a.requires_grad)
with torch.no_grad():
  print(a.requires_grad)
  b = a * 2

print(a.requires_grad)
print(b.requires_grad)
make_dot(b).render("./img/torchviz_4", format="png")
# Out:
# True
# True
# True
# False
# 'img/torchviz_4.png'

# %% [markdown]
# # d_autograd_3.py

# %%
import torch

# %%
weights = torch.ones(4, requires_grad=True)

for epoch in range(3):
    output = (weights * 3).sum()
    print("[output {0}]:".format(epoch), output)
    output.backward()

    print("weights.grad:", weights.grad)

    # optimize model, i.e. adjust weights...
    with torch.no_grad():
        weights -= 0.1 * weights.grad
        # 'empty gradients' is important!
        # It affects the final weights & output
        weights.grad.zero_()

    print("weights:", weights)
    print()

output = (weights * 3).sum()
print("\n[output final]:", output)
# Out:
# [output 0]: tensor(12., grad_fn=<SumBackward0>)
# weights.grad: tensor([3., 3., 3., 3.])
# weights: tensor([0.7000, 0.7000, 0.7000, 0.7000], requires_grad=True)
#
# [output 1]: tensor(8.4000, grad_fn=<SumBackward0>)
# weights.grad: tensor([3., 3., 3., 3.])
# weights: tensor([0.4000, 0.4000, 0.4000, 0.4000], requires_grad=True)
#
# [output 2]: tensor(4.8000, grad_fn=<SumBackward0>)
# weights.grad: tensor([3., 3., 3., 3.])
# weights: tensor([0.1000, 0.1000, 0.1000, 0.1000], requires_grad=True)
#
#
# [output final]: tensor(1.2000, grad_fn=<SumBackward0>)

# %%
weights = torch.ones(4, requires_grad=True)
optimizer = torch.optim.SGD([weights], lr=0.1)

for epoch in range(3):
    # just a dummy example
    output = (weights * 3).sum()
    print("[output {0}]:".format(epoch), output)
    output.backward()

    print("weights.grad:", weights.grad)

    # optimize model, i.e. adjust weights & empty gradients
    optimizer.step()
    optimizer.zero_grad()

    print("weights:", weights)
    print()

output = (weights * 3).sum()
print("\n[output final]:", output)
# Out:
# [output 0]: tensor(12., grad_fn=<SumBackward0>)
# weights.grad: tensor([3., 3., 3., 3.])
# weights: tensor([0.7000, 0.7000, 0.7000, 0.7000], requires_grad=True)
#
# [output 1]: tensor(8.4000, grad_fn=<SumBackward0>)
# weights.grad: tensor([3., 3., 3., 3.])
# weights: tensor([0.4000, 0.4000, 0.4000, 0.4000], requires_grad=True)
#
# [output 2]: tensor(4.8000, grad_fn=<SumBackward0>)
# weights.grad: tensor([3., 3., 3., 3.])
# weights: tensor([0.1000, 0.1000, 0.1000, 0.1000], requires_grad=True)
#
#
# [output final]: tensor(1.2000, grad_fn=<SumBackward0>)

# %% [markdown]
# # e_single_neuron_autograd_1.py

# %%
import torch
from torch.utils.data import DataLoader

# %%
def learn(W, b, train_data_loader):
    MAX_EPOCHS = 20_000
    LEARNING_RATE = 0.01

    for epoch in range(0, MAX_EPOCHS):
        batch = next(iter(train_data_loader))
        y_pred = model(batch["input"], W, b)
        loss = loss_fn(y_pred, batch["target"])

        loss.backward()

    if epoch % 100 == 0:
        print("[Epoch:{0:6,}] loss:{1:8.5f}, w0:{2:6.3f}, w1:{3:6.3f}, b:{4:6.3f}".format(
            epoch, loss.item(), W[0].item(), W[1].item(), b.item()
        ), end=", ")
        print("W.grad: {0}, b.grad:{1}".format(W.grad, b.grad))

    with torch.no_grad():
        W -= LEARNING_RATE * W.grad
        b -= LEARNING_RATE * b.grad
        W.grad = None
        b.grad = None

# %%
def main():
    W = torch.ones((2,), requires_grad=True)
    b = torch.zeros((1,), requires_grad=True)

    simple_dataset = SimpleDataset()
    train_data_loader = DataLoader(dataset=simple_dataset, batch_size=len(simple_dataset))
    learn(W, b, train_data_loader)

# %%
if __name__ == "__main__":
    main()

# %% [markdown]
# # f_single_neuron_autograd_2.py

# %%
import torch
from torch.utils.data import DataLoader

# %%
def learn(W, b, train_data_loader):
    MAX_EPOCHS = 20_000
    LEARNING_RATE = 0.01

    from torch import optim
    optimizer = optim.SGD([W, b], lr=LEARNING_RATE)

    for epoch in range(0, MAX_EPOCHS):
        batch = next(iter(train_data_loader))
        y_pred = model(batch["input"], W, b)
        loss = loss_fn(y_pred, batch["target"])

        loss.backward()

        if epoch % 100 == 0:
            print("[Epoch:{0:6,}] loss:{1:8.5f}, w0:{2:6.3f}, w1:{3:6.3f}, b:{4:6.3f}".format(
                epoch, loss.item(), W[0].item(), W[1].item(), b.item()
            ), end=", ")
            print("W.grad: {0}, b.grad:{1}".format(W.grad, b.grad))

        optimizer.step()
        optimizer.zero_grad()

# %%
def main():
    W = torch.ones((2,), requires_grad=True)
    b = torch.zeros((1,), requires_grad=True)

    simple_dataset = SimpleDataset()
    train_data_loader = DataLoader(dataset=simple_dataset, batch_size=len(simple_dataset))
    learn(W, b, train_data_loader)

# %%
if __name__ == "__main__":
    main()
# Out:
# [Epoch:     0] loss: 0.22539, w0: 1.000, w1: 1.000, b: 0.000, W.grad: tensor([0.0020, 0.0311]), b.grad:tensor([0.0271])
# [Epoch:   100] loss: 0.22369, w0: 0.998, w1: 0.969, b:-0.027, W.grad: tensor([0.0030, 0.0307]), b.grad:tensor([0.0269])
# [Epoch:   200] loss: 0.22203, w0: 0.994, w1: 0.939, b:-0.054, W.grad: tensor([0.0040, 0.0302]), b.grad:tensor([0.0267])
# [Epoch:   300] loss: 0.22041, w0: 0.989, w1: 0.909, b:-0.080, W.grad: tensor([0.0052, 0.0297]), b.grad:tensor([0.0264])
# [Epoch:   400] loss: 0.21882, w0: 0.984, w1: 0.879, b:-0.107, W.grad: tensor([0.0064, 0.0291]), b.grad:tensor([0.0261])
# [Epoch:   500] loss: 0.21727, w0: 0.977, w1: 0.850, b:-0.133, W.grad: tensor([0.0077, 0.0285]), b.grad:tensor([0.0258])
# [Epoch:   600] loss: 0.21575, w0: 0.968, w1: 0.822, b:-0.158, W.grad: tensor([0.0092, 0.0279]), b.grad:tensor([0.0254])
# [Epoch:   700] loss: 0.21425, w0: 0.958, w1: 0.795, b:-0.183, W.grad: tensor([0.0107, 0.0273]), b.grad:tensor([0.0251])
# [Epoch:   800] loss: 0.21276, w0: 0.947, w1: 0.768, b:-0.208, W.grad: tensor([0.0124, 0.0268]), b.grad:tensor([0.0248])
# [Epoch:   900] loss: 0.21128, w0: 0.934, w1: 0.741, b:-0.233, W.grad: tensor([0.0142, 0.0263]), b.grad:tensor([0.0246])
# [Epoch: 1,000] loss: 0.20977, w0: 0.918, w1: 0.715, b:-0.258, W.grad: tensor([0.0162, 0.0258]), b.grad:tensor([0.0243])
# [Epoch: 1,100] loss: 0.20823, w0: 0.901, w1: 0.689, b:-0.282, W.grad: tensor([0.0184, 0.0255]), b.grad:tensor([0.0242])
# [Epoch: 1,200] loss: 0.20661, w0: 0.881, w1: 0.664, b:-0.306, W.grad: tensor([0.0210, 0.0253]), b.grad:tensor([0.0241])
# [Epoch: 1,300] loss: 0.20489, w0: 0.859, w1: 0.639, b:-0.330, W.grad: tensor([0.0239, 0.0252]), b.grad:tensor([0.0241])
# [Epoch: 1,400] loss: 0.20301, w0: 0.833, w1: 0.614, b:-0.354, W.grad: tensor([0.0274, 0.0253]), b.grad:tensor([0.0243])
# [Epoch: 1,500] loss: 0.20090, w0: 0.804, w1: 0.588, b:-0.379, W.grad: tensor([0.0315, 0.0257]), b.grad:tensor([0.0247])
# [Epoch: 1,600] loss: 0.19844, w0: 0.770, w1: 0.562, b:-0.404, W.grad: tensor([0.0367, 0.0265]), b.grad:tensor([0.0253])
# [Epoch: 1,700] loss: 0.19545, w0: 0.730, w1: 0.535, b:-0.429, W.grad: tensor([0.0432, 0.0278]), b.grad:tensor([0.0263])
# [Epoch: 1,800] loss: 0.19167, w0: 0.683, w1: 0.506, b:-0.456, W.grad: tensor([0.0516, 0.0298]), b.grad:tensor([0.0277])
# [Epoch: 1,900] loss: 0.18661, w0: 0.626, w1: 0.475, b:-0.485, W.grad: tensor([0.0628, 0.0331]), b.grad:tensor([0.0299])
# [Epoch: 2,000] loss: 0.17944, w0: 0.556, w1: 0.439, b:-0.516, W.grad: tensor([0.0780, 0.0386]), b.grad:tensor([0.0329])
# [Epoch: 2,100] loss: 0.16868, w0: 0.469, w1: 0.396, b:-0.551, W.grad: tensor([0.0982, 0.0482]), b.grad:tensor([0.0369])
# [Epoch: 2,200] loss: 0.15149, w0: 0.358, w1: 0.340, b:-0.590, W.grad: tensor([0.1261, 0.0680]), b.grad:tensor([0.0413])
# [Epoch: 2,300] loss: 0.11672, w0: 0.205, w1: 0.247, b:-0.634, W.grad: tensor([0.2003, 0.1402]), b.grad:tensor([0.0466])
# [Epoch: 2,400] loss: 0.00297, w0: 0.000, w1: 0.083, b:-0.667, W.grad: tensor([-0.0003, -0.0002]), b.grad:tensor([0.0069])
# [Epoch: 2,500] loss: 0.00293, w0: 0.001, w1: 0.083, b:-0.674, W.grad: tensor([-0.0002, -0.0002]), b.grad:tensor([0.0066])
# [Epoch: 2,600] loss: 0.00288, w0: 0.001, w1: 0.084, b:-0.681, W.grad: tensor([-0.0002, -0.0002]), b.grad:tensor([0.0064])
# [Epoch: 2,700] loss: 0.00284, w0: 0.001, w1: 0.084, b:-0.687, W.grad: tensor([-0.0002, -0.0002]), b.grad:tensor([0.0061])
# [Epoch: 2,800] loss: 0.00281, w0: 0.001, w1: 0.084, b:-0.693, W.grad: tensor([-0.0002, -0.0002]), b.grad:tensor([0.0059])
# [Epoch: 2,900] loss: 0.00278, w0: 0.001, w1: 0.084, b:-0.699, W.grad: tensor([-0.0002, -0.0002]), b.grad:tensor([0.0056])
# [Epoch: 3,000] loss: 0.00275, w0: 0.002, w1: 0.084, b:-0.704, W.grad: tensor([-0.0002, -0.0002]), b.grad:tensor([0.0054])
# [Epoch: 3,100] loss: 0.00272, w0: 0.002, w1: 0.085, b:-0.709, W.grad: tensor([-0.0002, -0.0002]), b.grad:tensor([0.0052])
# [Epoch: 3,200] loss: 0.00269, w0: 0.002, w1: 0.085, b:-0.714, W.grad: tensor([-0.0002, -0.0002]), b.grad:tensor([0.0050])
# [Epoch: 3,300] loss: 0.00267, w0: 0.002, w1: 0.085, b:-0.719, W.grad: tensor([-0.0002, -0.0002]), b.grad:tensor([0.0048])
# [Epoch: 3,400] loss: 0.00265, w0: 0.002, w1: 0.085, b:-0.724, W.grad: tensor([-0.0002, -0.0002]), b.grad:tensor([0.0046])
# [Epoch: 3,500] loss: 0.00263, w0: 0.003, w1: 0.085, b:-0.728, W.grad: tensor([-0.0002, -0.0002]), b.grad:tensor([0.0044])
# [Epoch: 3,600] loss: 0.00261, w0: 0.003, w1: 0.085, b:-0.733, W.grad: tensor([-0.0002, -0.0002]), b.grad:tensor([0.0042])
# [Epoch: 3,700] loss: 0.00259, w0: 0.003, w1: 0.086, b:-0.737, W.grad: tensor([-0.0001, -0.0001]), b.grad:tensor([0.0040])
# [Epoch: 3,800] loss: 0.00258, w0: 0.003, w1: 0.086, b:-0.741, W.grad: tensor([-0.0001, -0.0001]), b.grad:tensor([0.0039])
# [Epoch: 3,900] loss: 0.00256, w0: 0.003, w1: 0.086, b:-0.745, W.grad: tensor([-0.0001, -0.0001]), b.grad:tensor([0.0037])
# [Epoch: 4,000] loss: 0.00255, w0: 0.003, w1: 0.086, b:-0.748, W.grad: tensor([-0.0001, -0.0001]), b.grad:tensor([0.0036])
# [Epoch: 4,100] loss: 0.00254, w0: 0.003, w1: 0.086, b:-0.752, W.grad: tensor([-0.0001, -0.0001]), b.grad:tensor([0.0034])
# [Epoch: 4,200] loss: 0.00252, w0: 0.003, w1: 0.086, b:-0.755, W.grad: tensor([-0.0001, -0.0001]), b.grad:tensor([0.0033])
# [Epoch: 4,300] loss: 0.00251, w0: 0.004, w1: 0.086, b:-0.758, W.grad: tensor([-0.0001, -0.0001]), b.grad:tensor([0.0032])
# [Epoch: 4,400] loss: 0.00250, w0: 0.004, w1: 0.086, b:-0.761, W.grad: tensor([-0.0001, -0.0001]), b.grad:tensor([0.0030])
# [Epoch: 4,500] loss: 0.00250, w0: 0.004, w1: 0.087, b:-0.764, W.grad: tensor([-0.0001, -0.0001]), b.grad:tensor([0.0029])
# [Epoch: 4,600] loss: 0.00249, w0: 0.004, w1: 0.087, b:-0.767, W.grad: tensor([-1.0408e-04, -9.8320e-05]), b.grad:tensor([0.0028])
# [Epoch: 4,700] loss: 0.00248, w0: 0.004, w1: 0.087, b:-0.770, W.grad: tensor([-1.0026e-04, -9.4137e-05]), b.grad:tensor([0.0027])
# [Epoch: 4,800] loss: 0.00247, w0: 0.004, w1: 0.087, b:-0.773, W.grad: tensor([-9.6692e-05, -9.0227e-05]), b.grad:tensor([0.0026])
# [Epoch: 4,900] loss: 0.00247, w0: 0.004, w1: 0.087, b:-0.775, W.grad: tensor([-9.3195e-05, -8.6414e-05]), b.grad:tensor([0.0025])
# [Epoch: 5,000] loss: 0.00246, w0: 0.004, w1: 0.087, b:-0.778, W.grad: tensor([-8.9824e-05, -8.2746e-05]), b.grad:tensor([0.0024])
# [Epoch: 5,100] loss: 0.00245, w0: 0.004, w1: 0.087, b:-0.780, W.grad: tensor([-8.6493e-05, -7.9188e-05]), b.grad:tensor([0.0023])
# [Epoch: 5,200] loss: 0.00245, w0: 0.004, w1: 0.087, b:-0.782, W.grad: tensor([-8.3589e-05, -7.6024e-05]), b.grad:tensor([0.0022])
# [Epoch: 5,300] loss: 0.00244, w0: 0.005, w1: 0.087, b:-0.784, W.grad: tensor([-8.0453e-05, -7.2700e-05]), b.grad:tensor([0.0021])
# [Epoch: 5,400] loss: 0.00244, w0: 0.005, w1: 0.087, b:-0.786, W.grad: tensor([-7.7614e-05, -6.9678e-05]), b.grad:tensor([0.0020])
# [Epoch: 5,500] loss: 0.00244, w0: 0.005, w1: 0.087, b:-0.788, W.grad: tensor([-7.4793e-05, -6.6722e-05]), b.grad:tensor([0.0020])
# [Epoch: 5,600] loss: 0.00243, w0: 0.005, w1: 0.087, b:-0.790, W.grad: tensor([-7.2263e-05, -6.4052e-05]), b.grad:tensor([0.0019])
# [Epoch: 5,700] loss: 0.00243, w0: 0.005, w1: 0.088, b:-0.792, W.grad: tensor([-6.9741e-05, -6.1423e-05]), b.grad:tensor([0.0018])
# [Epoch: 5,800] loss: 0.00243, w0: 0.005, w1: 0.088, b:-0.794, W.grad: tensor([-6.7179e-05, -5.8791e-05]), b.grad:tensor([0.0017])
# [Epoch: 5,900] loss: 0.00242, w0: 0.005, w1: 0.088, b:-0.796, W.grad: tensor([-6.4695e-05, -5.6267e-05]), b.grad:tensor([0.0017])
# [Epoch: 6,000] loss: 0.00242, w0: 0.005, w1: 0.088, b:-0.797, W.grad: tensor([-6.2460e-05, -5.3988e-05]), b.grad:tensor([0.0016])
# [Epoch: 6,100] loss: 0.00242, w0: 0.005, w1: 0.088, b:-0.799, W.grad: tensor([-6.0192e-05, -5.1712e-05]), b.grad:tensor([0.0015])
# [Epoch: 6,200] loss: 0.00242, w0: 0.005, w1: 0.088, b:-0.800, W.grad: tensor([-5.8011e-05, -4.9542e-05]), b.grad:tensor([0.0015])
# [Epoch: 6,300] loss: 0.00241, w0: 0.005, w1: 0.088, b:-0.802, W.grad: tensor([-5.6107e-05, -4.7638e-05]), b.grad:tensor([0.0014])
# [Epoch: 6,400] loss: 0.00241, w0: 0.005, w1: 0.088, b:-0.803, W.grad: tensor([-5.4142e-05, -4.5697e-05]), b.grad:tensor([0.0014])
# [Epoch: 6,500] loss: 0.00241, w0: 0.005, w1: 0.088, b:-0.805, W.grad: tensor([-5.2043e-05, -4.3683e-05]), b.grad:tensor([0.0013])
# [Epoch: 6,600] loss: 0.00241, w0: 0.005, w1: 0.088, b:-0.806, W.grad: tensor([-5.0311e-05, -4.1991e-05]), b.grad:tensor([0.0013])
# [Epoch: 6,700] loss: 0.00241, w0: 0.005, w1: 0.088, b:-0.807, W.grad: tensor([-4.8496e-05, -4.0253e-05]), b.grad:tensor([0.0012])
# [Epoch: 6,800] loss: 0.00241, w0: 0.006, w1: 0.088, b:-0.808, W.grad: tensor([-4.6561e-05, -3.8428e-05]), b.grad:tensor([0.0012])
# [Epoch: 6,900] loss: 0.00240, w0: 0.006, w1: 0.088, b:-0.810, W.grad: tensor([-4.4916e-05, -3.6878e-05]), b.grad:tensor([0.0011])
# [Epoch: 7,000] loss: 0.00240, w0: 0.006, w1: 0.088, b:-0.811, W.grad: tensor([-4.3291e-05, -3.5360e-05]), b.grad:tensor([0.0011])
# [Epoch: 7,100] loss: 0.00240, w0: 0.006, w1: 0.088, b:-0.812, W.grad: tensor([-4.1665e-05, -3.3855e-05]), b.grad:tensor([0.0011])
# [Epoch: 7,200] loss: 0.00240, w0: 0.006, w1: 0.088, b:-0.813, W.grad: tensor([-4.0436e-05, -3.2721e-05]), b.grad:tensor([0.0010])
# [Epoch: 7,300] loss: 0.00240, w0: 0.006, w1: 0.088, b:-0.814, W.grad: tensor([-3.9010e-05, -3.1398e-05]), b.grad:tensor([0.0010])
# [Epoch: 7,400] loss: 0.00240, w0: 0.006, w1: 0.088, b:-0.815, W.grad: tensor([-3.7572e-05, -3.0114e-05]), b.grad:tensor([0.0009])
# [Epoch: 7,500] loss: 0.00240, w0: 0.006, w1: 0.088, b:-0.816, W.grad: tensor([-3.6050e-05, -2.8744e-05]), b.grad:tensor([0.0009])
# [Epoch: 7,600] loss: 0.00240, w0: 0.006, w1: 0.088, b:-0.817, W.grad: tensor([-3.4980e-05, -2.7776e-05]), b.grad:tensor([0.0009])
# [Epoch: 7,700] loss: 0.00240, w0: 0.006, w1: 0.088, b:-0.817, W.grad: tensor([-3.3498e-05, -2.6474e-05]), b.grad:tensor([0.0008])
# [Epoch: 7,800] loss: 0.00240, w0: 0.006, w1: 0.088, b:-0.818, W.grad: tensor([-3.2566e-05, -2.5641e-05]), b.grad:tensor([0.0008])
# [Epoch: 7,900] loss: 0.00239, w0: 0.006, w1: 0.088, b:-0.819, W.grad: tensor([-3.1244e-05, -2.4486e-05]), b.grad:tensor([0.0008])
# [Epoch: 8,000] loss: 0.00239, w0: 0.006, w1: 0.088, b:-0.820, W.grad: tensor([-3.0141e-05, -2.3540e-05]), b.grad:tensor([0.0007])
# [Epoch: 8,100] loss: 0.00239, w0: 0.006, w1: 0.088, b:-0.820, W.grad: tensor([-2.9135e-05, -2.2669e-05]), b.grad:tensor([0.0007])
# [Epoch: 8,200] loss: 0.00239, w0: 0.006, w1: 0.088, b:-0.821, W.grad: tensor([-2.8015e-05, -2.1707e-05]), b.grad:tensor([0.0007])
# [Epoch: 8,300] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.822, W.grad: tensor([-2.6938e-05, -2.0794e-05]), b.grad:tensor([0.0007])
# [Epoch: 8,400] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.822, W.grad: tensor([-2.5916e-05, -1.9921e-05]), b.grad:tensor([0.0006])
# [Epoch: 8,500] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.823, W.grad: tensor([-2.5061e-05, -1.9201e-05]), b.grad:tensor([0.0006])
# [Epoch: 8,600] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.824, W.grad: tensor([-2.3990e-05, -1.8310e-05]), b.grad:tensor([0.0006])
# [Epoch: 8,700] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.824, W.grad: tensor([-2.3096e-05, -1.7564e-05]), b.grad:tensor([0.0006])
# [Epoch: 8,800] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.825, W.grad: tensor([-2.2419e-05, -1.7019e-05]), b.grad:tensor([0.0005])
# [Epoch: 8,900] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.825, W.grad: tensor([-2.1548e-05, -1.6309e-05]), b.grad:tensor([0.0005])
# [Epoch: 9,000] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.826, W.grad: tensor([-2.0957e-05, -1.5819e-05]), b.grad:tensor([0.0005])
# [Epoch: 9,100] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.826, W.grad: tensor([-2.0212e-05, -1.5216e-05]), b.grad:tensor([0.0005])
# [Epoch: 9,200] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.827, W.grad: tensor([-1.9477e-05, -1.4621e-05]), b.grad:tensor([0.0005])
# [Epoch: 9,300] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.827, W.grad: tensor([-1.8542e-05, -1.3839e-05]), b.grad:tensor([0.0005])
# [Epoch: 9,400] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.828, W.grad: tensor([-1.7988e-05, -1.3433e-05]), b.grad:tensor([0.0004])
# [Epoch: 9,500] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.828, W.grad: tensor([-1.7273e-05, -1.2850e-05]), b.grad:tensor([0.0004])
# [Epoch: 9,600] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.829, W.grad: tensor([-1.6561e-05, -1.2269e-05]), b.grad:tensor([0.0004])
# [Epoch: 9,700] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.829, W.grad: tensor([-1.6073e-05, -1.1898e-05]), b.grad:tensor([0.0004])
# [Epoch: 9,800] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.829, W.grad: tensor([-1.5572e-05, -1.1504e-05]), b.grad:tensor([0.0004])
# [Epoch: 9,900] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.830, W.grad: tensor([-1.4890e-05, -1.0965e-05]), b.grad:tensor([0.0004])
# [Epoch:10,000] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.830, W.grad: tensor([-1.4548e-05, -1.0708e-05]), b.grad:tensor([0.0003])
# [Epoch:10,100] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.830, W.grad: tensor([-1.3847e-05, -1.0155e-05]), b.grad:tensor([0.0003])
# [Epoch:10,200] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.831, W.grad: tensor([-1.3481e-05, -9.8934e-06]), b.grad:tensor([0.0003])
# [Epoch:10,300] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.831, W.grad: tensor([-1.2693e-05, -9.2424e-06]), b.grad:tensor([0.0003])
# [Epoch:10,400] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.831, W.grad: tensor([-1.2524e-05, -9.1558e-06]), b.grad:tensor([0.0003])
# [Epoch:10,500] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.832, W.grad: tensor([-1.1815e-05, -8.5747e-06]), b.grad:tensor([0.0003])
# [Epoch:10,600] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.832, W.grad: tensor([-1.1559e-05, -8.4080e-06]), b.grad:tensor([0.0003])
# [Epoch:10,700] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.832, W.grad: tensor([-1.0862e-05, -7.8445e-06]), b.grad:tensor([0.0003])
# [Epoch:10,800] loss: 0.00239, w0: 0.006, w1: 0.089, b:-0.832, W.grad: tensor([-1.0772e-05, -7.8082e-06]), b.grad:tensor([0.0003])
# [Epoch:10,900] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.833, W.grad: tensor([-1.0199e-05, -7.3789e-06]), b.grad:tensor([0.0002])
# [Epoch:11,000] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.833, W.grad: tensor([-9.9419e-06, -7.1693e-06]), b.grad:tensor([0.0002])
# [Epoch:11,100] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.833, W.grad: tensor([-9.6210e-06, -6.9439e-06]), b.grad:tensor([0.0002])
# [Epoch:11,200] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.833, W.grad: tensor([-9.2343e-06, -6.6664e-06]), b.grad:tensor([0.0002])
# [Epoch:11,300] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.834, W.grad: tensor([-8.8410e-06, -6.3386e-06]), b.grad:tensor([0.0002])
# [Epoch:11,400] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.834, W.grad: tensor([-8.7116e-06, -6.2911e-06]), b.grad:tensor([0.0002])
# [Epoch:11,500] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.834, W.grad: tensor([-8.2257e-06, -5.9111e-06]), b.grad:tensor([0.0002])
# [Epoch:11,600] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.834, W.grad: tensor([-7.8601e-06, -5.6121e-06]), b.grad:tensor([0.0002])
# [Epoch:11,700] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.834, W.grad: tensor([-7.6783e-06, -5.4939e-06]), b.grad:tensor([0.0002])
# [Epoch:11,800] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.835, W.grad: tensor([-7.1938e-06, -5.1279e-06]), b.grad:tensor([0.0002])
# [Epoch:11,900] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.835, W.grad: tensor([-6.8787e-06, -4.8839e-06]), b.grad:tensor([0.0002])
# [Epoch:12,000] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.835, W.grad: tensor([-6.7656e-06, -4.8215e-06]), b.grad:tensor([0.0002])
# [Epoch:12,100] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.835, W.grad: tensor([-6.5528e-06, -4.6734e-06]), b.grad:tensor([0.0002])
# [Epoch:12,200] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.835, W.grad: tensor([-6.2943e-06, -4.4992e-06]), b.grad:tensor([0.0001])
# [Epoch:12,300] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.835, W.grad: tensor([-5.9074e-06, -4.1854e-06]), b.grad:tensor([0.0001])
# [Epoch:12,400] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.836, W.grad: tensor([-5.8352e-06, -4.1360e-06]), b.grad:tensor([0.0001])
# [Epoch:12,500] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.836, W.grad: tensor([-5.6096e-06, -3.9730e-06]), b.grad:tensor([0.0001])
# [Epoch:12,600] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.836, W.grad: tensor([-5.6466e-06, -4.0587e-06]), b.grad:tensor([0.0001])
# [Epoch:12,700] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.836, W.grad: tensor([-5.2983e-06, -3.7896e-06]), b.grad:tensor([0.0001])
# [Epoch:12,800] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.836, W.grad: tensor([-4.8778e-06, -3.4273e-06]), b.grad:tensor([0.0001])
# [Epoch:12,900] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.836, W.grad: tensor([-4.8210e-06, -3.3844e-06]), b.grad:tensor([0.0001])
# [Epoch:13,000] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.836, W.grad: tensor([-4.6827e-06, -3.3015e-06]), b.grad:tensor([0.0001])
# [Epoch:13,100] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.836, W.grad: tensor([-4.6249e-06, -3.2987e-06]), b.grad:tensor([0.0001])
# [Epoch:13,200] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.836, W.grad: tensor([-4.3074e-06, -3.0557e-06]), b.grad:tensor([0.0001])
# [Epoch:13,300] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.837, W.grad: tensor([-4.2745e-06, -3.0529e-06]), b.grad:tensor([9.8311e-05])
# [Epoch:13,400] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.837, W.grad: tensor([-3.9532e-06, -2.7819e-06]), b.grad:tensor([9.4707e-05])
# [Epoch:13,500] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.837, W.grad: tensor([-3.6550e-06, -2.5136e-06]), b.grad:tensor([9.1176e-05])
# [Epoch:13,600] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.837, W.grad: tensor([-3.6927e-06, -2.5770e-06]), b.grad:tensor([8.7777e-05])
# [Epoch:13,700] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.837, W.grad: tensor([-3.6750e-06, -2.5900e-06]), b.grad:tensor([8.4509e-05])
# [Epoch:13,800] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.837, W.grad: tensor([-3.5339e-06, -2.5127e-06]), b.grad:tensor([8.1343e-05])
# [Epoch:13,900] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.837, W.grad: tensor([-3.4007e-06, -2.4270e-06]), b.grad:tensor([7.8339e-05])
# [Epoch:14,000] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.837, W.grad: tensor([-3.3854e-06, -2.4494e-06]), b.grad:tensor([7.5395e-05])
# [Epoch:14,100] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.837, W.grad: tensor([-2.8801e-06, -2.0191e-06]), b.grad:tensor([7.2635e-05])
# [Epoch:14,200] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.837, W.grad: tensor([-2.9388e-06, -2.0545e-06]), b.grad:tensor([6.9912e-05])
# [Epoch:14,300] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.837, W.grad: tensor([-2.7120e-06, -1.8515e-06]), b.grad:tensor([6.7319e-05])
# [Epoch:14,400] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.837, W.grad: tensor([-2.7409e-06, -1.8878e-06]), b.grad:tensor([6.4826e-05])
# [Epoch:14,500] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-2.7444e-06, -1.8887e-06]), b.grad:tensor([6.2352e-05])
# [Epoch:14,600] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-2.5844e-06, -1.8002e-06]), b.grad:tensor([6.0096e-05])
# [Epoch:14,700] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-2.6561e-06, -1.8915e-06]), b.grad:tensor([5.7822e-05])
# [Epoch:14,800] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-2.3474e-06, -1.6615e-06]), b.grad:tensor([5.5683e-05])
# [Epoch:14,900] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-2.2943e-06, -1.6447e-06]), b.grad:tensor([5.3646e-05])
# [Epoch:15,000] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-2.4354e-06, -1.8049e-06]), b.grad:tensor([5.1596e-05])
# [Epoch:15,100] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.9297e-06, -1.3914e-06]), b.grad:tensor([4.9714e-05])
# [Epoch:15,200] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-2.0016e-06, -1.4426e-06]), b.grad:tensor([4.7898e-05])
# [Epoch:15,300] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.8617e-06, -1.3243e-06]), b.grad:tensor([4.6093e-05])
# [Epoch:15,400] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.6866e-06, -1.1558e-06]), b.grad:tensor([4.4345e-05])
# [Epoch:15,500] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.6405e-06, -1.1185e-06]), b.grad:tensor([4.2762e-05])
# [Epoch:15,600] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.6517e-06, -1.1204e-06]), b.grad:tensor([4.1174e-05])
# [Epoch:15,700] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.6263e-06, -1.0896e-06]), b.grad:tensor([3.9592e-05])
# [Epoch:15,800] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.5842e-06, -1.0654e-06]), b.grad:tensor([3.8120e-05])
# [Epoch:15,900] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.5618e-06, -1.0710e-06]), b.grad:tensor([3.6757e-05])
# [Epoch:16,000] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.5353e-06, -1.0617e-06]), b.grad:tensor([3.5401e-05])
# [Epoch:16,100] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.5395e-06, -1.0887e-06]), b.grad:tensor([3.4041e-05])
# [Epoch:16,200] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.4498e-06, -1.0347e-06]), b.grad:tensor([3.2702e-05])
# [Epoch:16,300] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.4133e-06, -1.0375e-06]), b.grad:tensor([3.1572e-05])
# [Epoch:16,400] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.3602e-06, -1.0217e-06]), b.grad:tensor([3.0445e-05])
# [Epoch:16,500] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.3676e-06, -1.0561e-06]), b.grad:tensor([2.9310e-05])
# [Epoch:16,600] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.3716e-06, -1.0841e-06]), b.grad:tensor([2.8176e-05])
# [Epoch:16,700] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-1.3746e-06, -1.1018e-06]), b.grad:tensor([2.7043e-05])
# [Epoch:16,800] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.838, W.grad: tensor([-9.6485e-07, -7.6089e-07]), b.grad:tensor([2.6121e-05])
# [Epoch:16,900] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-9.8487e-07, -7.7207e-07]), b.grad:tensor([2.5209e-05])
# [Epoch:17,000] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-1.0310e-06, -8.0839e-07]), b.grad:tensor([2.4302e-05])
# [Epoch:17,100] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-9.1223e-07, -7.0687e-07]), b.grad:tensor([2.3402e-05])
# [Epoch:17,200] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-9.7253e-07, -7.5344e-07]), b.grad:tensor([2.2495e-05])
# [Epoch:17,300] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-1.0380e-06, -8.1025e-07]), b.grad:tensor([2.1585e-05])
# [Epoch:17,400] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-6.3190e-07, -4.5449e-07]), b.grad:tensor([2.0753e-05])
# [Epoch:17,500] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-7.1852e-07, -4.9733e-07]), b.grad:tensor([2.0064e-05])
# [Epoch:17,600] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-6.3190e-07, -3.9861e-07]), b.grad:tensor([1.9394e-05])
# [Epoch:17,700] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-6.2119e-07, -3.7719e-07]), b.grad:tensor([1.8714e-05])
# [Epoch:17,800] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-5.9791e-07, -3.4086e-07]), b.grad:tensor([1.8039e-05])
# [Epoch:17,900] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-7.0268e-07, -4.2189e-07]), b.grad:tensor([1.7351e-05])
# [Epoch:18,000] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-7.2550e-07, -4.2934e-07]), b.grad:tensor([1.6670e-05])
# [Epoch:18,100] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-7.5856e-07, -4.4703e-07]), b.grad:tensor([1.5994e-05])
# [Epoch:18,200] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-7.8231e-07, -4.5821e-07]), b.grad:tensor([1.5310e-05])
# [Epoch:18,300] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-6.6822e-07, -3.7067e-07]), b.grad:tensor([1.4722e-05])
# [Epoch:18,400] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-6.0536e-07, -3.4738e-07]), b.grad:tensor([1.4275e-05])
# [Epoch:18,500] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-6.5193e-07, -4.1351e-07]), b.grad:tensor([1.3819e-05])
# [Epoch:18,600] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-5.8091e-07, -3.6508e-07]), b.grad:tensor([1.3371e-05])
# [Epoch:18,700] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-5.0711e-07, -3.0920e-07]), b.grad:tensor([1.2921e-05])
# [Epoch:18,800] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-5.6904e-07, -3.8743e-07]), b.grad:tensor([1.2462e-05])
# [Epoch:18,900] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-5.8836e-07, -4.1910e-07]), b.grad:tensor([1.2007e-05])
# [Epoch:19,000] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-4.4866e-07, -2.9989e-07]), b.grad:tensor([1.1565e-05])
# [Epoch:19,100] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-5.4669e-07, -3.9674e-07]), b.grad:tensor([1.1104e-05])
# [Epoch:19,200] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-5.8627e-07, -4.3400e-07]), b.grad:tensor([1.0651e-05])
# [Epoch:19,300] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-4.6520e-07, -3.2783e-07]), b.grad:tensor([1.0207e-05])
# [Epoch:19,400] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-4.5681e-07, -3.2689e-07]), b.grad:tensor([9.7528e-06])
# [Epoch:19,500] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-5.2317e-07, -3.8743e-07]), b.grad:tensor([9.2969e-06])
# [Epoch:19,600] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-3.7812e-07, -2.6636e-07]), b.grad:tensor([8.8993e-06])
# [Epoch:19,700] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-4.0489e-07, -3.2689e-07]), b.grad:tensor([8.6718e-06])
# [Epoch:19,800] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-3.1316e-07, -2.7288e-07]), b.grad:tensor([8.4501e-06])
# [Epoch:19,900] loss: 0.00239, w0: 0.007, w1: 0.089, b:-0.839, W.grad: tensor([-3.0361e-07, -2.9523e-07]), b.grad:tensor([8.2231e-06])
